# %% [markdown]
# ## Data ingestion
#
# from langchain

# %%
#document

from langchain_core.documents import Document

doc = Document(page_content="This is a test document.", 
               metadata={"source": "test.txt", "author": "John Doe", "page": 1})

doc
# Out:
# Document(metadata={'source': 'test.txt', 'author': 'John Doe', 'page': 1}, page_content='This is a test document.')

# %%
## create simple txt file
import os
os.makedirs("../data/pdf", exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for file_path, content in sample_texts.items():
    with open(file_path, "w") as f:
        f.write(content)

        print(f"Created file: {file_path}")
# Out:
# Created file: ../data/text_files/python_intro.txt
# Created file: ../data/text_files/machine_learning.txt

# %%
### text loader

from langchain.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader("../data/text_files", glob="*.txt",loader_cls=TextLoader, show_progress=False)
dir_loader.load()
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.'),
#  Document(metadata={'source': '../data/text_files/machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n    \n    \n    ')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

dir_loader = DirectoryLoader("../data/pdf", glob="*.pdf",loader_cls=PyMuPDFLoader, show_progress=False)
dir_loader.load()
# Out:
# [Document(metadata={'producer': 'Microsoft® Excel® for Microsoft 365', 'creator': 'Microsoft® Excel® for Microsoft 365', 'creationdate': '2025-02-11T20:23:13-05:00', 'source': '../data/pdf/Module 14 Glossary.pdf', 'file_path': '../data/pdf/Module 14 Glossary.pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': '', 'author': 'Pickard, John', 'subject': '', 'keywords': '', 'moddate': '2025-02-11T20:23:13-05:00', 'trapped': '', 'modDate': "D:20250211202313-05'00'", 'creationDate': "D:20250211202313-05'00'", 'page': 0}, page_content='Term\nDefinition\nAAA (Authentication, \nAuthorization, and \nAccounting)\nA framework that authenticates users, authorizes access to resources, and \naccounts for user activities.\nACS (Access Control \nServer)\nA server used to manage access to network resources and enforce security \npolicies.\nClient\nSoftware that sends requests to a server and processes the response, e.g., web \nbrowsers like Chrome or Firefox.\nDNS (Domain Name \nSystem)\nA hierarchical system for translating human-readable domain names into IP \naddresses.\nFTP (File Transfer Protocol)\nA protocol used to transfer files between a client and server over a network.\nHTTP (Hypertext Transfer \nProtocol)\nAn application-layer protocol used for transmitting hypermedia documents, \nsuch as HTML.\nHTTPS (Hypertext Transfer \nProtocol Secure)\nThe secure version of HTTP that uses encryption to protect data transmitted \nbetween a browser and server.\nISA/IEC (International \nSociety of \nAutomation/International \nElectrotechnical \nCommission)\nOrganizations that develop international standards for industrial automation \nand electrical systems.\nNERC CIP (North American \nElectric Reliability \nCorporation - Critical \nInfrastructure Protection)\nA set of standards to protect critical infrastructure in the North American electric \npower system.\nNIST (National Institute of \nStandards and Technology)\nA U.S. agency that develops and promotes standards for technology, science, \nand cybersecurity.\nNNTP (Network News \nTransfer Protocol)\nA protocol used to distribute, retrieve, and post news articles over a network.\nRADIUS (Remote \nAuthentication Dial-in User \nService)\nA protocol that provides centralized authentication, authorization, and \naccounting for network access.'),
#  Document(metadata={'producer': 'Microsoft® Excel® for Microsoft 365', 'creator': 'Microsoft® Excel® for Microsoft 365', 'creationdate': '2025-02-11T20:23:13-05:00', 'source': '../data/pdf/Module 14 Glossary.pdf', 'file_path': '../data/pdf/Module 14 Glossary.pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': '', 'author': 'Pickard, John', 'subject': '', 'keywords': '', 'moddate': '2025-02-11T20:23:13-05:00', 'trapped': '', 'modDate': "D:20250211202313-05'00'", 'creationDate': "D:20250211202313-05'00'", 'page': 1}, page_content='Server\nA host running a software application that provides information or services to \nother hosts connected to the network.\nSFTP (Secure File Transfer \nProtocol)\nA secure version of FTP that encrypts file transfers to prevent unauthorized \naccess.\nSSH (Secure Shell)\nA secure protocol for remote command-line access and file transfers over a \nnetwork.\nTACACS (Remote \nAuthentication Dial-in User \nService)\nA protocol used for centralized authentication of users accessing a network.\nTelnet\nAn application-layer protocol for accessing devices remotely using a command-\nline interface; not secure.\nURI (Uniform Resource \nIdentifier)\nA string of characters that identifies a specific network resource; it includes \nprotocols, hostnames, and paths.\nURL (Uniform Resource \nLocator)\nDefines the network location of a specific resource on the network, typically \nused with HTTP or HTTPS.\nURN (Uniform Resource \nName)\nIdentifies the namespace of the resource without reference to the protocol.\nVPN (Virtual Private \nNetwork)\nA virtual private network that provides secure, encrypted communication over \npublic networks.')]
